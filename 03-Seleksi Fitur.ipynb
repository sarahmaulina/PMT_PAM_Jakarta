# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('updated_wilayah_pampat.csv', index_col=0)
df.head()
# Out:
#       Tanggal          Kecamatan      pam    pat   elevasi    bulan  \
# 0  2018-01-01          Kalideres  1154930  17945  5.352066  January
# 1  2018-01-01         Cengkareng   883655  13730  3.352066  January
# 2  2018-01-01            Tambora      128      2  4.352066  January
# 3  2018-01-01  Grogol Petamburan   373284   5800  4.352066  January
# 4  2018-01-01         Taman Sari   207430   3223  5.352066  January
#
#    bulan_num  tahun        wilayah
# 0          1   2018  Jakarta Barat
# 1          1   2018  Jakarta Barat
# 2          1   2018  Jakarta Barat
# 3          1   2018  Jakarta Barat
# 4          1   2018  Jakarta Barat

# %%
df['kecamatan_num'] = df['Kecamatan'].map({
    "Kalideres": 1, "Cengkareng": 2, "Tambora": 3,
    "Grogol Petamburan": 4, "Taman Sari": 5, "Kebon Jeruk": 6,
    "Kembangan": 7, "Palmerah": 8, "Menteng": 9,
    "Tanah Abang": 10, "Sawah Besar": 11, "Gambir": 12,
    "Cempaka Putih": 13, "Johar Baru": 14, "Kemayoran": 15,
    "Senen": 16, "Kramat Jati": 17, "Ciracas": 18,
    "Cipayung": 19, "Makasar": 20, "Pasar Rebo": 21,
    "Jatinegara": 22, "Duren sawit": 23, "Matraman": 24,
    "Pulo Gadung": 25, "Cakung": 26, "Tanjung Priok": 27, 
    "Cilincing": 28, "Kelapa gading": 29, "Koja": 30,
    "Pademangan": 31, "Penjaringan": 32, "Setiabudi": 33,
    "Tebet": 34, "Keb Baru": 35, "Keb Lama": 36,
    "Cilandak": 37, "Pesanggrahan": 38, "Pasar Minggu": 39,
    "Jagakarsa": 40, "Mampang Prapatan": 41, "Pancoran": 42,
})

# %%
df['wilayah_num'] = df['wilayah'].map({
    "Jakarta Barat": 1, "Jakarta Pusat": 2, "Jakarta Timur": 3,
    "Jakarta Utara": 4, "Jakarta Selatan": 5,
})

# %%
df.head()
# Out:
#       Tanggal          Kecamatan      pam    pat   elevasi    bulan  \
# 0  2018-01-01          Kalideres  1154930  17945  5.352066  January
# 1  2018-01-01         Cengkareng   883655  13730  3.352066  January
# 2  2018-01-01            Tambora      128      2  4.352066  January
# 3  2018-01-01  Grogol Petamburan   373284   5800  4.352066  January
# 4  2018-01-01         Taman Sari   207430   3223  5.352066  January
#
#    bulan_num  tahun        wilayah  kecamatan_num  wilayah_num
# 0          1   2018  Jakarta Barat              1            1
# 1          1   2018  Jakarta Barat              2            1
# 2          1   2018  Jakarta Barat              3            1
# 3          1   2018  Jakarta Barat              4            1
# 4          1   2018  Jakarta Barat              5            1

# %%
df.drop(columns=['Tanggal','bulan','wilayah'],inplace=True)

# %%
df.head()
# Out:
#       Tanggal          Kecamatan      pam    pat   elevasi    bulan  \
# 0  2018-01-01          Kalideres  1154930  17945  5.352066  January
# 1  2018-01-01         Cengkareng   883655  13730  3.352066  January
# 2  2018-01-01            Tambora      128      2  4.352066  January
# 3  2018-01-01  Grogol Petamburan   373284   5800  4.352066  January
# 4  2018-01-01         Taman Sari   207430   3223  5.352066  January
#
#    bulan_num  tahun        wilayah  kecamatan_num  wilayah_num
# 0          1   2018  Jakarta Barat              1            1
# 1          1   2018  Jakarta Barat              2            1
# 2          1   2018  Jakarta Barat              3            1
# 3          1   2018  Jakarta Barat              4            1
# 4          1   2018  Jakarta Barat              5            1

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(), cmap='Blues', annot=True)
plt.show()
